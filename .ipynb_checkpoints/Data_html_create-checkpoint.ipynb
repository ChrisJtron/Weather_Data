# %%
import pandas as pd

# %%
path = "weather.csv"
data=pd.read_csv(path)
data.head()
# Out:
#    Unnamed: 0       City  Latitude  Longitude  Temperature  Humidity  Clouds  \
# 0           0  ostrovnoy     68.05      39.51        50.47        93      63
# 1           1  mahebourg    -20.41      57.70        71.60        88      75
# 2           2    qaanaaq     77.48     -69.36        41.09        66       1
# 3           3     zhuhai     22.28     113.57        81.61        88      40
# 4           4  cape town    -33.93      18.42        53.91        93       0
#
#    Wind Speed
# 0        9.06
# 1        5.82
# 2        1.83
# 3       21.92
# 4        6.93

# %%
html= data.to_html()
html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Humidity</th>\n      <th>Clouds</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>ostrovnoy</td>\n      <td>68.05</td>\n      <td>39.51</td>\n      <td>50.47</td>\n      <td>93</td>\n      <td>63</td>\n      <td>9.06</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>mahebourg</td>\n      <td>-20.41</td>\n      <td>57.70</td>\n      <td>71.60</td>\n      <td>88</td>\n      <td>75</td>\n      <td>5.82</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>qaanaaq</td>\n      <td>77.48</td>\n      <td>-69.36</td>\n      <td>41.09</td>\n      <td>66</td>\n      <td>1</td>\n      <td>1.83</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <
# ...

# %%
#write html to file
text_file = open("index.html", "w")
text_file.write(html)
text_file.close()

# %%
data.to_html('Data_html.html')
